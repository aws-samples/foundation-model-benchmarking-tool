# %% [markdown]
# ## Setup required for all notebooks
# ---------------------
# *This notebook works best with the conda_python3 kernel on a ml.t3.medium machine*.
#
# **This step of our solution design covers running setup steps that need to be run prior to any other notebook being run.**
#
# 1. Prerequisite: a `Python 3.11` conda environment.

# %% [markdown]
# #### Import all of the necessary libraries below to run this notebook

# %%
# if interactive mode is set to no -> pickup fmbench from Python installation path
# if interactive mode is set to yes -> pickup fmbench from the current path (one level above this notebook)
# if interactive mode is not defined -> pickup fmbench from the current path (one level above this notebook)
# the premise is that if run non-interactively then it can only be run through main.py which will set interactive mode to no
import os
import sys
if os.environ.get("INTERACTIVE_MODE_SET", "yes") == "yes":
    sys.path.append(os.path.dirname(os.getcwd()))

# %%
import sys
import time
import json
import boto3
import asyncio
import logging
import importlib.util
import fmbench.scripts
from pathlib import Path
from fmbench.utils import *
from fmbench.globals import *
from typing import Dict, List, Optional
from sagemaker import get_execution_role
import importlib.resources as pkg_resources
from botocore.exceptions import ClientError
from botocore.exceptions import NoCredentialsError
# Out:
# config file current -> configs/config-claude-models.yml, None
# Loaded config: {'general': {'name': 'fmbench-claude', 'model_name': 'claude'}, 'aws': {'region': 'us-east-1', 'sagemaker_execution_role': 'arn:aws:iam::121797993273:user/ab3', 'bucket': 'sagemaker-fmbench-write-121797993273'}, 'dir_paths': {'data_prefix': 'data', 'prompts_prefix': 'prompts', 'all_prompts_file': 'all_prompts.csv', 'metrics_dir': 'metrics', 'models_dir': 'models', 'metadata_dir': 'metadata'}, 's3_read_data': {'read_bucket': 'sagemaker-fmbench-read-121797993273', 'scripts_prefix': 'scripts', 'script_files': ['hf_token.txt'], 'source_data_prefix': 'source_data', 'tokenizer_prefix': 'tokenizer', 'prompt_template_dir': 'prompt_template', 'prompt_template_file': 'prompt_template.txt'}, 'run_steps': {'0_setup.ipynb': True, '1_generate_data.ipynb': True, '2_deploy_model.ipynb': False, '3_run_inference.ipynb': True, '4_model_metric_analysis.ipynb': True, '5_cleanup.ipynb': True}, 'datasets': {'prompt_template_keys': ['input', 'context'], 'filters': [{'language': 'en', 'min_length_in_tokens': 1, 'max_length_in_tokens': 500, 'payload_file': 'payload_en_1-500.jsonl'}, {'language': 'en', 'min_length_in_tokens': 500, 'max_length_in_tokens': 1000, 'payload_file': 'payload_en_500-1000.jsonl'}, {'language': 'en', 'min_length_in_tokens': 1000, 'max_length_in_tokens': 2000, 'payload_file': 'payload_en_1000-2000.jsonl'}, {'language': 'en', 'min_length_in_tokens': 2000, 'max_length_in_tokens': 3000, 'payload_file': 'payload_en_2000-3000.jsonl'}, {'language': 'en', 'min_length_in_tokens': 3000, 'max_length_in_tokens': 4000, 'payload_file': 'payload_en_3000-4000.jsonl'}, {'language': 'en', 'min_length_in_tokens': 305, 'max_length_in_tokens': 3997, 'payload_file': 'payload_en_305-3997.jsonl'}]}, 'metrics': {'dataset_of_interest': 'en_1000-2000', 'weights': {'price_per_tx_wt': 0.65, 'latenct_wt': 0.35}}, 'pricing': {'ml.m5.xlarge': 0.23, 'ml.g5.xlarge': 1.006, 'ml.g5.2xlarge': 1.212, 'ml.g5.12xlarge': 7.09, 'ml.g5.24xlarge': 10.18, 'ml.g5.48xlarge': 20.36, 'ml.inf2.24xlarge': 7.79, 'ml.inf2.48xlarge': 15.58, 'ml.p4d.24xlarge': 37.688, 'ml.p3.2xlarge': 3.825, 'Claudev3-Haiku-ODT': [{'input-per-1k-tokens': 0.00025}, {'output-per-1k-tokens': 0.00125}], 'Claudev3-Sonnet-ODT': [{'input-per-1k-tokens': 0.003}, {'output-per-1k-tokens': 0.015}], 'ClaudeV2-ODT': [{'input-per-1k-tokens': 0.0008}, {'output-per-1k-tokens': 0.0024}], 'ClaudeV2:1-ODT': [{'input-per-1k-tokens': 0.0008}, {'output-per-1k-tokens': 0.0024}], 'ClaudeInstant-ODT': [{'input-per-1k-tokens': 0.0008}, {'output-per-1k-tokens': 0.0024}], 'titan-emb-text-ODT': [{'input-per-1k-tokens': 0.0001}, {'output-per-1k-tokens': 0}], 'titan-text-lite-ODT': [{'input-per-1k-tokens': 0.0003}, {'output-per-1k-tokens': 0.0004}], 'titan-text-express-ODT': [{'input-per-1k-tokens': 0.0008}, {'output-per-1k-tokens': 0.0016}], 'Mistral-ODT': [{'input-per-1k-tokens': 0.00015}, {'output-per-1k-tokens': 0.0002}], 'Mixtral-ODT': [{'input-per-1k-tokens': 0.00045}, {'output-per-1k-tokens': 0.0007}], 'Llama13b-ODT': [{'input-per-1k-tokens': 0.00075}, {'output-per-1k-tokens': 0.001}], 'Llama70b-ODT': [{'input-per-1k-tokens': 0.00195}, {'output-per-1k-tokens': 0.00195}], 'AI21mid-ODT': [{'input-per-1k-tokens': 0.0125}, {'output-per-1k-tokens': 0.0125}], 'AI21ultra-ODT': [{'input-per-1k-tokens': 0.0188}, {'output-per-1k-tokens': 0.0188}], 'CohereCommand-ODT': [{'input-per-1k-tokens': 0.0015}, {'output-per-1k-tokens': 0.002}], 'CohereCommLight-ODT': [{'input-per-1k-tokens': 0.0003}, {'output-per-1k-tokens': 0.0006}]}, 'inference_parameters': {'ContentType': 'application/json', 'Accept': 'application/json'}, 'experiments': [{'name': 'claude-instant-v1', 'model_id': 'anthropic.claude-instant-v1', 'model_version': '*', 'model_name': 'claude-instant-v1', 'ep_name': 'anthropic.claude-instant-v1', 'instance_type': 'ClaudeInstant-ODT', 'image_uri': None, 'deploy': False, 'instance_count': 1, 'deployment_script': None, 'inference_script': 'bedrock_predictor.py', 'inference_spec': {'split_input_and_parameters': False},  ...
# CustomTokenizer, based on HF transformers
# No files found in S3 Bucket: 'sagemaker-fmbench-read-121797993273' with Prefix: 'tokenizer'
# sagemaker.config INFO - Not applying SDK defaults from location: /opt/homebrew/share/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/madhurpt/Library/Application Support/sagemaker/config.yaml

# %% [markdown]
# #### Pygmentize globals.py to view and use any of the globally initialized variables

# %% [markdown]
# #### Set up a logger to log all messages while the code runs

# %%
logging.basicConfig(format='[%(asctime)s] p%(process)s {%(filename)s:%(lineno)d} %(levelname)s - %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Load the config.yml file
# ------
#
# The config.yml file contains information that is used across this benchmarking environment, such as information about the aws account, prompts, payloads to be used for invocations, and model configurations like the version of the model, the endpoint name, model_id that needs to be deployed. Configurations also support the gives instance type to be used, for example: "ml.g5.24xlarge", the image uri, whether or not to deploy this given model, followed by an inference script "jumpstart.py" which supports the inference script for jumpstart models to deploy the model in this deploy notebook.
#
# View the contents of the config yml file below and how it is loaded and used throughout this notebook with deploying the model endpoints asynchronously.

# %%
## Load the config.yml file referring to the globals.py file
config = load_config(CONFIG_FILE)

## configure the aws region and execution role
aws_region = config['aws']['region']


try:
    sagemaker_execution_role = get_execution_role()
    config['aws']['sagemaker_execution_role'] = sagemaker_execution_role
    logger.info(f"determined SageMaker exeuction role from get_execution_role")
except Exception as e:
    logger.error(f"could not determine SageMaker execution role, error={e}")
    logger.info(f"going to look for execution role in config file..")
    sagemaker_execution_role = config['aws'].get('sagemaker_execution_role')
    if sagemaker_execution_role is not None:
        logger.info(f"found SageMaker execution role in config file..")

logger.info(f"aws_region={aws_region}, sagemaker_execution_role={sagemaker_execution_role}")
logger.info(f"config={json.dumps(config, indent=2)}")
# Out:
# [2024-03-23 11:23:53,876] p56458 {session.py:5460} WARNING - Couldn't call 'get_role' to get Role ARN from role name ab3 to get Role path.
# [2024-03-23 11:23:53,879] p56458 {2048960905.py:13} ERROR - could not determine SageMaker execution role, error=The current AWS identity is not a role: arn:aws:iam::121797993273:user/ab3, therefore it cannot be used as a SageMaker execution role
# [2024-03-23 11:23:53,880] p56458 {2048960905.py:14} INFO - going to look for execution role in config file..
# [2024-03-23 11:23:53,880] p56458 {2048960905.py:17} INFO - found SageMaker execution role in config file..
# [2024-03-23 11:23:53,881] p56458 {2048960905.py:19} INFO - aws_region=us-east-1, sagemaker_execution_role=arn:aws:iam::121797993273:user/ab3
# [2024-03-23 11:23:53,882] p56458 {2048960905.py:20} INFO - config={
#   "general": {
#     "name": "fmbench-claude",
#     "model_name": "claude"
#   },
#   "aws": {
#     "region": "us-east-1",
#     "sagemaker_execution_role": "arn:aws:iam::121797993273:user/ab3",
#     "bucket": "sagemaker-fmbench-write-121797993273"
#   },
#   "dir_paths": {
#     "data_prefix": "data",
#     "prompts_prefix": "prompts",
#     "all_prompts_file": "all_prompts.csv",
#     "metrics_dir": "metrics",
#     "models_dir": "models",
#     "metadata_dir": "metadata"
#   },
#   "s3_read_data": {
#     "read_bucket": "sagemaker-fmbench-read-121797993273",
#     "scripts_prefix": "scripts",
#     "script_files": [
#       "hf_token.txt"
#     ],
#     "source_data_prefix": "source_data",
#     "tokenizer_prefix": "tokenizer",
#     "prompt_template_dir": "prompt_template",
#     "prompt_template_file": "prompt_template.txt"
#   },
#   "run_steps": {
#     "0_setup.ipynb": true,
#     "1_generate_data.ipynb": true,
#     "2_deploy_model.ipynb": false,
#     "3_run_inference.ipynb": true,
#     "4_model_metric_analysis.ipynb": true,
#     "5_cleanup.ipynb": true
#   },
#   "datasets": {
#     "prompt_template_keys": [
#       "input",
#       "context"
#     ],
#     "filters": [
#       {
#         "language": "en",
#         "min_length_in_tokens": 1,
#         "max_length_in_tokens": 500,
#         "payload_file": "payload_en_1-500.jsonl"
#       },
#       {
#         "language": "en",
#         "min_length_in_tokens": 500,
#         "max_length_in_tokens": 1000,
#         "payload_file": "payload_en_500-1000.jsonl"
#       },
#       {
#         "language": "en",
#         "min_length_in_tokens": 1000,
#         "max_length_in_tokens": 2000,
#         "payload_file": "payload_en_1000-2000.jsonl"
#       },
#       {
#         "language": "en",
#         "min_length_in_tokens": 2000,
#         "max_length_in_tokens": 3000,
#         "payload_file": "payload_en_2000-3000.jsonl"
#       },
#       {
#         "language": "en",
#         "min_length_in_tokens": 3000,
#         "max_length_in_tokens": 4000,
#         "payload_file": "payload_en_3000-4000.jsonl"
#       },
#       {
#         "language": "en",
#         "min_length_in_tokens": 305,
#         "max_length_in_tokens": 3997,
#         "payload_file": "payload_en_305-3997.jsonl"
#       }
#     ]
#   },
#   "metrics": {
#     "dataset_of_interest": "en_1000-2000",
#     "weights": {
#       "price_per_tx_wt": 0.65,
#       "latenct_wt": 0.35
#     }
#   },
#   "pricing": {
#     "ml.m5.xlarge": 0.23,
#     "ml.g5.xlarge": 1.006,
#     "ml.g5.2xlarge": 1.212,
#     "ml.g5.12xlarge": 7.09,
#     "ml.g5.24xlarge": 10.18,
#     "ml.g5.48xlarge": 20.36,
#     "ml.inf2.24xlarge": 7.79,
#     "ml.inf2.48xlarge": 15.58,
#     "ml.p4d.24xlarge": 37.688,
#     "ml.p3.2xlarge": 3.825,
#     "Claudev3-Haiku-ODT": [
#       {
#         "input-per-1k-tokens": 0.00025
#       },
#       {
#         "output-per-1k-tokens": 0.00125
#       }
#     ],
#     "Claudev3-Sonnet-ODT": [
#       {
#         "input-per-1k-tokens": 0.003
#       },
#       {
#         "output-per-1k-tokens": 0.015
#       }
#     ],
#     "ClaudeV2-ODT": [
#       {
#         "input-per-1k-tokens": 0.0008
#       },
#       {
#         "output-per-1k-tokens": 0.0024
#       }
#     ],
#     "ClaudeV2:1-ODT": [
#       {
#         "input-per-1k-tokens": 0.0008
#       },
#       {
#         "output-per-1k-tokens": 0.0024
#       }
#     ],
#     "ClaudeInstant-ODT": [
#       {
#         "input-per-1k-tokens": 0.0008
#       },
#       {
#         "output-per-1k-tokens": 0.0024
#       }
#     ],
#     "titan-emb-text-ODT": [
#       {
#         "input-per-1k-tokens": 0.0001
#       },
#       {
#         "output-per-1k-tokens": 0
#       }
#     ],
#     "titan-text-lite-ODT": [
#       {
#         "input-per-1k-tokens": 0.0003
#       },
#       {
#         "output-per-1k-tokens": 0.0004
#       }
#     ],
#     "titan-text-express-ODT": [
#       {
#         "input-per-1k-tokens": 0.0008
#       },
#       {
#         "output-per-1k-tokens": 0.0016
#       }
#     ],
#     "Mistral-ODT": [
#       {
#         "input-per-1k-tokens": 0.00015
#       },
#       {
#         "output-per-1k-tokens": 0.0002
#       }
#     ],
#     "Mixtral-ODT": [
#       {
#         "input-per-1k-tokens": 0.00045
#       },
#       {
#         "output-per-1k-tokens": 0.0007
#       }
#     ],
#     "Llama13b-ODT": [
#       {
#         "input-per-1k-tokens": 0.00075
#       },
#       {
#         "output-per-1k-tokens": 0.001
#       }
#     ],
#     "Llama70b-ODT": [
#       {
#         "input-per-1k-tokens": 0.00195
#       },
#       {
#         "output-per-1k-tokens": 0.00195
#       }
#     ],
#     "AI21mid-ODT": [
#       {
#         "input-per-1k-tokens": 0.0125
#       },
#       {
#         "output-per-1k-tokens": 0.0125
#       }
#     ],
#     "AI21ultra-ODT": [
#       {
#         "input-per-1k-tokens": 0.0188
#       },
#       {
#         "output-per-1k-tokens": 0.0188
#       }
#     ],
#     "CohereCommand-ODT": [
#       {
#         "input-per-1k-tokens": 0.0015
#       },
#       {
#         "output-per-1k-tokens": 0.002
#       }
#     ],
#     "CohereCommLight-ODT": [
#       {
#         "input-per-1k-tokens": 0.0003
#       },
#       {
#         "output-per-1k-tokens": 0.0006
#       }
#     ]
#   },
#   "inference_parameters": {
#     "ContentType": "application/json",
#     "Accept": "application/json"
#   },
#   "experiments": [
#     {
#       "name": "claude-instant-v1",
#       "model_id": "anthropic.claude-instant-v1",
#       "model_version": "*",
#       "model_name": "claude-instant-v1",
#       "ep_name": "anthropic.claude-instant-v1",
#       "instance_type": "ClaudeInstant-ODT",
#       "image_uri": null,
#       "deploy": false,
#       "instance_count": 1,
#       "deployment_script": null,
#       "inference_script": "bedrock_predictor.py",
#       "inference_spec": {
#         "split_input_and_parameters": false
#       },
#       "payload_files": [
#         "payload_en_1000-2000.jsonl"
#       ],
#       "concurrency_levels": [
#         1
#       ],
#       "env": null
#     },
#     {
#       "name": "haiku-bedrock-trial",
#       "model_id": "anthropic.claude-3-haiku-20240307-v1:0",
#       "model_version": "*",
#       "model_name": "haiku",
#       "ep_name": "anthropic.claude-3-haiku-20240307-v1:0",
#       "instance_type": "Claudev3-Haiku-ODT",
#       "image_uri": null,
#       "deploy": false,
#       "instance_count": 1,
#       "deployment_script": null,
#       "inference_script": "bedrock_predictor.py",
#       "inference_spec": {
#         "split_input_and_parameters": false
#       },
#       "payload_files": [
#         "payload_en_3000-4000.jsonl"
#       ],
#       "concurrency_levels": [
#         1
#       ],
#       "env": null
#     },
#     {
#       "name": "claude-v2",
#       "model_id": "anthropic.claude-v2",
#       "model_version": "*",
#       "model_name": "claude-v2",
#       "ep_name": "anthropic.claude-v2",
#       "instance_type": "ClaudeV2-ODT",
#       "image_uri": null,
#       "deploy": false,
#       "instance_count": 1,
#       "deployment_script": null,
#       "inference_script": "bedrock_predictor.py",
#       "inference_spec": {
#         "split_input_and_parameters": false
#       },
#       "payload_files": [
#         "payload_en_3000-4000.jsonl"
#       ],
#       "concurrency_levels": [
#         1,
#         2,
#         4
#       ],
#       "env": null
#     },
#     {
#       "name": "claude-3-sonnet",
#       "model_id": "anthropic.claude-3-sonnet-20240229-v1:0",
#       "model_version": "*",
#       "model_name": "claude-3-sonnet",
#       "ep_name": "anthropic.claude-3-sonnet-20240229-v1:0",
#       "instance_type": "Claudev3-Sonnet-ODT",
#       "image_uri": null,
#       "deploy": false,
#       "instance_count": 1,
#       "deployment_script": null,
#       "inference_script": "bedrock_predictor.py",
#       "inference_spec": {
#         "split_input_and_parameters": false
#       },
#       "payload_files": [
#         "payload_en_3000-4000.jsonl"
#       ],
#       "concurrency_levels": [
#         1
#       ],
#       "env": null
#     },
#     {
#       "name": "claude-v2:1",
#       "model_id": "anthropic.claude-v2:1",
#       "model_version": "*",
#       "model_name": "claude-v2:1",
#       "ep_name": "anthropic.claude-v2:1",
#       "instance_type": "ClaudeV2:1-ODT",
#       "image_uri": null,
#       "deploy": false,
#       "instance_count": 1,
#       "deployment_script": null,
#       "inference_script": "bedrock_predictor.py",
#       "inference_spec": {
#         "split_input_and_parameters": false
#       },
#       "payload_files": [
#         "payload_en_3000-4000.jsonl"
#       ],
#       "concurrency_levels": [
#         1,
#         2,
#         4
#       ],
#       "env": null
#     }
#   ],
#   "report": {
#     "per_inference_request_file": "per_inference_request_results.csv",
#     "all_metrics_file": "all_metrics.csv",
#     "txn_count_for_showing_cost": 100000,
#     "v_shift_w_single_instance": 0.025,
#     "v_shift_w_gt_one_instance": 0.025
#   }
# }

# %% [markdown]
# #### Install packages listed in the `requirements.txt` file

# %%
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ipywidgets==8.1.1 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (8.1.1)
# Requirement already satisfied: sagemaker==2.203.0 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.203.0)
# Requirement already satisfied: transformers==4.36.2 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (4.36.2)
# Requirement already satisfied: pandas==2.1.4 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.1.4)
# Requirement already satisfied: datasets==2.16.1 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2.16.1)
# Requirement already satisfied: seaborn==0.13.1 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.13.1)
# Requirement already satisfied: tomark==0.1.4 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: anthropic==0.2.8 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.2.8)
# Requirement already satisfied: anthropic-bedrock==0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (0.8.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 1)) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 1)) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 1)) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: attrs<24,>=23.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: boto3<2.0,>=1.33.3 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (1.34.49)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: google-pasta in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (6.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pathos in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: schema in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: PyYAML~=6.0 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: jsonschema in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (4.19.1)
# Requirement already satisfied: platformdirs in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: tblib<3,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: urllib3<1.27 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: uvicorn==0.22.0 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (0.22.0)
# Requirement already satisfied: fastapi==0.95.2 in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (0.95.2)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: docker in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (6.1.3)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (4.66.1)
# Requirement already satisfied: psutil in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from sagemaker==2.203.0->-r requirements.txt (line 2)) (5.9.6)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from transformers==4.36.2->-r requirements.txt (line 3)) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/homebrew/lib/python3.11/site-packages (from transformers==4.36.2->-r requirements.txt (line 3)) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/lib/python3.11/site-packages (from transformers==4.36.2->-r requirements.txt (line 3)) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/homebrew/lib/python3.11/site-packages (from transformers==4.36.2->-r requirements.txt (line 3)) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/homebrew/lib/python3.11/site-packages (from transformers==4.36.2->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas==2.1.4->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas==2.1.4->-r requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas==2.1.4->-r requirements.txt (line 4)) (2023.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/homebrew/lib/python3.11/site-packages (from datasets==2.16.1->-r requirements.txt (line 5)) (13.0.0)
# Requirement already satisfied: pyarrow-hotfix in /opt/homebrew/lib/python3.11/site-packages (from datasets==2.16.1->-r requirements.txt (line 5)) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from datasets==2.16.1->-r requirements.txt (line 5)) (0.3.7)
# Requirement already satisfied: xxhash in /opt/homebrew/lib/python3.11/site-packages (from datasets==2.16.1->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/homebrew/lib/python3.11/site-packages (from datasets==2.16.1->-r requirements.txt (line 5)) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /opt/homebrew/lib/python3.11/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.16.1->-r requirements.txt (line 5)) (2023.10.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/lib/python3.11/site-packages (from datasets==2.16.1->-r requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/lib/python3.11/site-packages (from seaborn==0.13.1->-r requirements.txt (line 6)) (3.8.2)
# Requirement already satisfied: httpx in /opt/homebrew/lib/python3.11/site-packages (from anthropic==0.2.8->-r requirements.txt (line 8)) (0.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (3.7.1)
# Requirement already satisfied: botocore>=1.31.57 in /opt/homebrew/lib/python3.11/site-packages (from anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (1.34.49)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/homebrew/lib/python3.11/site-packages (from anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (1.10.14)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/homebrew/lib/python3.11/site-packages (from anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/homebrew/lib/python3.11/site-packages (from fastapi==0.95.2->sagemaker==2.203.0->-r requirements.txt (line 2)) (0.27.0)
# Requirement already satisfied: click>=7.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn==0.22.0->sagemaker==2.203.0->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn==0.22.0->sagemaker==2.203.0->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<5,>=3.5.0->anthropic-bedrock==0.8.0->-r requirements.txt (line 9)) (3.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0,>=1.33.3->sagemaker==2.203.0->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0,>=1.33.3->sagemaker==2.203.0->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->datasets==2.16.1->-r requirements.txt (line 5)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->datasets==2.16.1->-r requirements.txt (line 5)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->datasets==2.16.1->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->datasets==2.16.1->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx->anthropic==0.2.8->-r requirements.txt (line 8)) (2023.7.22)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /opt/homebrew/lib/python3.11/site-packages (from httpx->anthropic==0.2.8->-r requirements.txt (line 8)) (0.17.3)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker==2.203.0->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: decorator in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (2.17.2)
# Requirement already satisfied: stack-data in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1->-r requirements.txt (line 6)) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1->-r requirements.txt (line 6)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.1->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.1.4->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->sagemaker==2.203.0->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from docker->sagemaker==2.203.0->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema->sagemaker==2.203.0->-r requirements.txt (line 2)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema->sagemaker==2.203.0->-r requirements.txt (line 2)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema->sagemaker==2.203.0->-r requirements.txt (line 2)) (0.17.1)
# Requirement already satisfied: ppft>=1.7.6.7 in /opt/homebrew/lib/python3.11/site-packages (from pathos->sagemaker==2.203.0->-r requirements.txt (line 2)) (1.7.6.7)
# Requirement already satisfied: pox>=0.3.3 in /opt/homebrew/lib/python3.11/site-packages (from pathos->sagemaker==2.203.0->-r requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: contextlib2>=0.5.5 in /opt/homebrew/lib/python3.11/site-packages (from schema->sagemaker==2.203.0->-r requirements.txt (line 2)) (21.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/madhurpt/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 1)) (0.2.2)

# %% [markdown]
# #### Download any scripts from Amazon S3
#
# Users can upload scripts to S3 which contain custom code for deployment and inference. We download these scripts here and place them in the `fmbench` package installation directory.

# %%
# Initialize the S3 client
s3_client = boto3.client('s3', region_name=aws_region)

# Assuming fmbench is a valid Python package and scripts is a subdirectory within it
scripts_dir = Path(pkg_resources.files('fmbench'), 'scripts')
logger.info(f"Using fmbench.scripts directory: {scripts_dir}")

# Ensure the scripts directory exists
scripts_dir.mkdir(parents=True, exist_ok=True)

read_bucket = config['s3_read_data']['read_bucket']
logger.info(f"the read bucket is --> {read_bucket} for reading the script files")
scripts_prefix = config['s3_read_data']['scripts_prefix']
logger.info(f"the scripts directory is --> {scripts_prefix} for reading the script file names")
script_files = config['s3_read_data'].get('script_files', [])
logger.info(f"Extracted script files that the user has provided --> {script_files}")

# Download script files to the fmbench.scripts directory
try:
    for script_name in script_files:
        # do os.path.join
        s3_script_path = f"{scripts_prefix}/{script_name}"
        ## take this out of the loop 
        logger.info(f"the script path for where the scripts you have entered in s3 will be installed --> {s3_script_path}")
        local_script_path = scripts_dir / script_name
        logger.info(f"Downloading {s3_script_path} to {local_script_path}")
        s3_client.download_file(read_bucket, s3_script_path, str(local_script_path))
except ClientError as error:
    logger.error(f"Failed to download script files: {error}")
# Out:
# [2024-03-23 11:23:57,300] p56458 {837909898.py:6} INFO - Using fmbench.scripts directory: /Users/madhurpt/Documents/foundation-model-benchmarking-tool-10/src/fmbench/scripts
# [2024-03-23 11:23:57,301] p56458 {837909898.py:12} INFO - the read bucket is --> sagemaker-fmbench-read-121797993273 for reading the script files
# [2024-03-23 11:23:57,301] p56458 {837909898.py:14} INFO - the scripts directory is --> scripts for reading the script file names
# [2024-03-23 11:23:57,301] p56458 {837909898.py:16} INFO - Extracted script files that the user has provided --> ['hf_token.txt']
# [2024-03-23 11:23:57,301] p56458 {837909898.py:24} INFO - the script path for where the scripts you have entered in s3 will be installed --> scripts/hf_token.txt
# [2024-03-23 11:23:57,302] p56458 {837909898.py:26} INFO - Downloading scripts/hf_token.txt to /Users/madhurpt/Documents/foundation-model-benchmarking-tool-10/src/fmbench/scripts/hf_token.txt
# [2024-03-23 11:23:57,490] p56458 {837909898.py:29} ERROR - Failed to download script files: An error occurred (404) when calling the HeadObject operation: Not Found
